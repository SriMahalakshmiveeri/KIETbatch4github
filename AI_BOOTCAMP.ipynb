# %% [markdown]
# <a href="https://colab.research.google.com/github/SriMahalakshmiveeri/KIETbatch4github/blob/main/AI_BOOTCAMP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #GOAL:
# set up YOLO(YOU ONLY LOOK ONCE) and detect objects in a single image
#
# . install and import YOLO
#
# . Load pretrained model
#
# . Run inference on an image
#
# . Display results

# %%
pip install -q ultralytics opencv-python-headless matplotlib pillow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 30.1 MB/s eta 0:00:00

# %%
from ultralytics import YOLO
import cv2
from matplotlib import pyplot as plt
from PIL import Image
from google.colab import files
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
uploaded = files.upload()
file_name=list(uploaded.keys())[0]
print(file_name)
# Out:
#      <input type="file" id="files-acbabf24-3f53-49e6-9213-1ccd7a1d935e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-acbabf24-3f53-49e6-9213-1ccd7a1d935e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
model = YOLO('yolov8n.pt')

# %%
results=model(file_name)
annotated=results[0].plot()
# Out:
# image 1/1 /content/OIP.jpeg: 576x640 1 dog, 44.1ms
# Speed: 2.8ms preprocess, 44.1ms inference, 274.3ms postprocess per image at shape (1, 3, 576, 640)

# %%
plt.figure(figsize=(12,8))
plt.imshow(cv2.cvtColor(annotated,cv2.COLOR_BGR2RGB))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(304.5), np.float64(273.5), np.float64(-0.5))
